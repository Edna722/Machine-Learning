# %%
import pandas as pd
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

#Metrics and machine learning libraries 
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.cluster import KMeans

# %%
customer_data = pd.read_csv(r"C:\Users\wanji\Downloads\Mall_Customers.csv")
customer_data.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %% [markdown]
# ## Univariate Analysis
# * Statistics

# %%
customer_data.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
sns.distplot(customer_data['Annual Income (k$)'])
# Out:
# <Axes: xlabel='Annual Income (k$)', ylabel='Density'>

# %%
customer_data.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
columns = ['Age', 'Annual Income (k$)','Spending Score (1-100)']
for i in columns:
    plt.figure()
    sns.distplot(customer_data[i])

# %%
# Ensure the hue column is specified correctly within sns.histplot
sns.histplot(data=customer_data, x='Annual Income (k$)', hue='Gender', kde=True, element="step")
# Out:
# <Axes: xlabel='Annual Income (k$)', ylabel='Count'>

# %%
columns = ['Age', 'Annual Income (k$)','Spending Score (1-100)']
for i in columns:
    plt.figure()
    sns.histplot(data=customer_data, x= i, hue='Gender', kde=True, element="step")

# %%
columns = ['Age', 'Annual Income (k$)','Spending Score (1-100)']
for i in columns:
    plt.figure()
    sns.boxplot(data=customer_data, x= 'Gender',y = customer_data[i])

# %%
customer_data['Gender'].value_counts(normalize = True)
# Out:
# Gender
# Female    0.56
# Male      0.44
# Name: proportion, dtype: float64

# %% [markdown]
# ## Bivariate Analysis
# ** Two Variables

# %%
sns.scatterplot(data = customer_data, x = 'Annual Income (k$)',y = 'Spending Score (1-100)')
# Out:
# <Axes: xlabel='Annual Income (k$)', ylabel='Spending Score (1-100)'>

# %%
# customer_data = customer_data.drop('CustomerID', axis =1 )
sns.pairplot(customer_data, hue = 'Gender')

# %%
customer_data.groupby(['Gender'])[['Age', 'Annual Income (k$)',
                                  'Spending Score (1-100)']].mean()
# Out:
#               Age  Annual Income (k$)  Spending Score (1-100)
# Gender
# Female  38.098214           59.250000               51.526786
# Male    39.806818           62.227273               48.511364

# %%
customer_data.corr( ['Age','Annual Income (k$)','Spending Score (1-100)'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-414c7371b073> in <module>
# ----> 1 customer_data.corr( ['Age','Annual Income (k$)','Spending Score (1-100)'])
#
# c:\Users\wanji\anaconda3\envs\learn-env\lib\site-packages\pandas\core\frame.py in corr(self, method, min_periods, numeric_only)
#   10052         cols = data.columns
#   10053         idx = cols.copy()
# > 10054         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10055
#   10056         if method == "pearson":
#
# c:\Users\wanji\anaconda3\envs\learn-env\lib\site-packages\pandas\core\frame.py in to_numpy(self, dtype, copy, na_value)
#    1836         if dtype is not None:
#    1837             dtype = np.dtype(dtype)
# -> 1838         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839         if result.dtype is not dtype:
# ...
